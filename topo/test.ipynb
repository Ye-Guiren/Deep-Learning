# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import numpy as np
from scipy.stats import norm  # 用于高斯函数D(T)计算
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import CosineAnnealingLR

# 设备配置（CPU/GPU）
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)  # 固定随机种子
np.random.seed(42)

# %%
# -------------------------- 几何参数-------------------------------
d0 = 0.05  # 内管直径（m）
d1 = 0.13  # 外壳直径（m）
r0 = d0 / 2  # 内管半径
r1 = d1 / 2  # 外壳半径

# -------------------------- 材料热物性参数--------------------------
# PCM（石蜡）
rho_s = 880.0    # 固相密度 (kg/m³)
rho_l = 760.0    # 液相密度 (kg/m³)
cp_s = 2180.0    # 固相定压比热容 (J/(kg·K))
cp_l = 2390.0    # 液相定压比热容 (J/(kg·K))
lambda_s = 0.4   # 固相导热系数 (W/(m·K))
lambda_l = 0.15  # 液相导热系数 (W/(m·K))
mu_l = 0.001     # 液相粘度 (kg/(m·s))
L = 255000.0     # 相变潜热 (J/kg)，文档L=255kJ/kg转换为J/kg
Tpc = 316.15     # 相变温度 (K)
DeltaT = 6.0     # 相变温度区间 (K)

# 高导热材料（铜）
rho_Cu = 8960.0  # 密度 (kg/m³)
lambda_Cu = 400.0  # 导热系数 (W/(m·K))
cp_Cu = 385.0    # 定压比热容 (J/(kg·K))
mu_Cu = 1e10     # 铜为固体，粘度取极大值抑制流动

# 外壳材料（铝）- 仅用于边界，此处拓扑优化设计域为PCM+铜，铝不参与设计
cp_Al = 879.0    # 定压比热容 (J/(kg·K))

# -------------------------- 物理模型参数-------------------------------
Am = 1e5         # 糊状区常数（文献常用值，文档未明确）
epsilon = 0.001  # 避免分母为0（文档方程4）
xi = 1.0         # 粘度函数常数（文档方程10）
alpha = 1e-4     # PCM体胀系数 (1/K)，自然对流计算需
g = 9.81         # 重力加速度 (m/s²)

# -------------------------- 拓扑优化参数--------------------------------
phi_total = 0.3  # 高导热材料体积比约束（预设，工程常用0.3）
case = 3         # 优化目标选择：1=平均温度，2=温度均方差，3=多目标
w1, w2, w3 = 1.0, 1.0, 1.0  # 多目标权重

# -------------------------- 训练超参数 --------------------------
N_mass = 10000   # 质量守恒方程采样点数量
N_mom = 10000    # 动量方程采样点数量
N_heat = 10000   # 传热方程采样点数量
N_IC = 8000      # 初始条件采样点数量
N_BC1 = 3000     # 内管壁边界采样点数量
N_BC2 = 3000     # 外壳边界采样点数量
N_rho = 10000    # 拓扑设计变量采样点数量
N_vol = 10000    # 体积比约束采样点数量
N_obj = 10000    # 优化目标采样点数量

# 损失项权重
lambda1 = 1e3    # PDE损失权重
lambda2 = 1.5e4    # IC/BC损失权重
lambda3 = 5.0   # 拓扑约束损失权重
lambda4 = 1.0    # 优化目标损失权重

# %%
class ResidualBlock(nn.Module):
    """残差块：缓解深层网络梯度消失，提升表达能力"""
    def __init__(self, dim):
        super(ResidualBlock, self).__init__()
        self.fc1 = nn.Linear(dim, dim)
        self.fc2 = nn.Linear(dim, dim)
        self.tanh = nn.Tanh()  # 保持与原网络一致的激活函数
    
    def forward(self, x):
        residual = x  # 残差连接：保留输入特征
        out = self.tanh(self.fc1(x))
        out = self.fc2(out)
        return self.tanh(out + residual)  # 残差相加后激活
        
class TopoPINN(nn.Module):
    def __init__(self, input_dim=3, output_dim=6, hidden_layers=6, hidden_dim=256):
        super(TopoPINN, self).__init__()
        # 输入层：3维（x,y,τ）→ hidden_dim维
        self.input_layer = nn.Linear(input_dim, hidden_dim)
        # 隐藏层：6个残差块（提升表达能力，匹配复杂耦合关系）
        self.hidden_layers = nn.ModuleList([ResidualBlock(hidden_dim) for _ in range(hidden_layers)])
        # 输出层：hidden_dim维→6维（ux, uy, p, T, φ, ρx）
        self.output_layer = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # x: [batch_size, 3]，对应(x,y,τ)
        out = self.input_layer(x)
        out = torch.tanh(out)  # 输入层后激活
        for layer in self.hidden_layers:
            out = layer(out)
        # 输出层无激活，后续对物理量进行归一化约束
        out = self.output_layer(out)
        # 分离输出并归一化（平衡物理量量级，提升训练稳定性）
        ux = out[:, 0:1] * 1e-3  # 速度量级：1e-3 m/s
        uy = out[:, 1:2] * 1e-3
        p = out[:, 2:3] * 1e3    # 压力量级：1e3 Pa（流动压力）
        T = out[:, 3:4] * 50 + 300  # 温度量级：250-350 K（50*[-1,1]+300）
        phi = torch.sigmoid(out[:, 4:5])  # 液相率∈[0,1]（sigmoid约束更平滑）
        rho_x = torch.sigmoid(out[:, 5:6])  # 拓扑变量∈[0,1]
        return ux, uy, p, T, phi, rho_x

# %%
def compute_thermo_props(phi, rho_x, T):
    """
    计算混合材料的热物性参数（PCM+铜）
    输入：phi(T)（液相率）、rho_x（拓扑设计变量）、T（温度）
    输出：rho_total, lambda_total, mu_total, cp_total, a（热扩散率）
    """
    # -------------------------- 1. 液相率φ的物理约束--------------------------
    # 虽然后续有损失项约束，但此处先做数值裁剪，避免计算溢出
    phi = torch.clamp(phi, 1e-6, 1.0 - 1e-6)  # φ∈[1e-6, 0.999]

    # -------------------------- 2. 密度ρ_total--------------------------
    # PCM密度：ρ_PCM = ρ_s + (ρ_l - ρ_s)*φ
    rho_PCM = rho_s + (rho_l - rho_s) * phi
    # 混合密度：ρ_total = ρx*ρ_Cu + (1-ρx)*ρ_PCM（铜占比ρx，PCM占比1-ρx）
    rho_total = rho_x * rho_Cu + (1.0 - rho_x) * rho_PCM

    # -------------------------- 3. 导热系数λ_total--------------------------
    lambda_PCM = lambda_s + (lambda_l - lambda_s) * phi
    lambda_total = rho_x * lambda_Cu + (1.0 - rho_x) * lambda_PCM

    # -------------------------- 4. 粘度mu_total--------------------------
    # 糊状区源项S_t(T)
    S_t = Am * ((1.0 - phi) ** 2) / (phi ** 3 + epsilon + 1e-10)  # 新增1e-10，增强稳定性
    # PCM粘度
    mu_PCM = mu_l + S_t * xi + 1e-10  # 避免mu_PCM=0
    # 混合粘度：铜为固体，mu_Cu取1e10抑制流动
    mu_total = rho_x * mu_Cu + (1.0 - rho_x) * mu_PCM
    # 运动粘度ν = μ/ρ
    nu = mu_total / rho_total

    # -------------------------- 5. 定压比热容cp_total--------------------------
    # D(T)：高斯函数，平滑化相变潜热
    sigma = DeltaT / 4.0  # 标准差
    D_T = torch.exp(-((T - Tpc) ** 2) / (sigma ** 2)) / (torch.sqrt(torch.tensor(np.pi)) * sigma)
    D_T = torch.clamp(D_T, 0.0, 1e3)  # 裁剪D_T
    # PCM比热容
    cp_PCM = cp_s + phi * (cp_l - cp_s) + L * D_T
    # 混合比热容：铜占比ρx，PCM占比1-ρx
    cp_total = rho_x * cp_Cu + (1.0 - rho_x) * cp_PCM

    # -------------------------- 6. 热扩散率a--------------------------
    a = lambda_total / (rho_total * cp_total + 1e-10)

    return rho_total, lambda_total, mu_total, nu, cp_total, a, S_t

# %%
def sample_collocation_points(N):
    """采样设计域内配点（x,y,τ）+ 面积元权重，用于PDE损失计算"""
    # 1. 时间τ采样：τ∈[0, 1e5s]，归一化到[0,1]便于训练
    tau = np.random.uniform(0.0, 1e5, size=(N, 1))  # [N,1]
    tau_norm = tau / 1e5  # 归一化到[0,1]

    # 2. 环形域（x,y）采样：极坐标转换（避免采样到域外）
    r = np.random.uniform(r0, r1, size=(N, 1))  # 半径∈[r0, r1]
    theta = np.random.uniform(0.0, 2*np.pi, size=(N, 1))  # 角度∈[0,2π]
    x = r * np.cos(theta)  # x坐标
    y = r * np.sin(theta)  # y坐标

    # 3. 输入归一化：x,y∈[-r1, r1]→归一化到[-1,1]，提升训练稳定性
    x_norm = x / r1
    y_norm = y / r1

    # 4. 面积元权重：环形域dA=r*dr*dθ，假设dr/dθ均匀，权重≈r（归一化后）
    weight = r / np.mean(r)  # 归一化权重（总和为N，便于平均）

    # 合并为输入张量：[N, 3] = (x_norm, y_norm, tau_norm)
    points = np.hstack([x_norm, y_norm, tau_norm])
    return (torch.tensor(points, dtype=torch.float32).to(device),
            torch.tensor(weight, dtype=torch.float32).to(device))  # 返回（配点，权重）

def adaptive_sample(model, N, prev_points, prev_weights, prev_residuals, residual_threshold=0.1):
    """
    自适应采样：聚焦高残差区域，提升关键区域精度
    prev_points: 上一轮配点 [N,3]
    prev_residuals: 上一轮传热残差 [N,1]
    residual_threshold: 高残差阈值（取前20%）
    """
    # 1. 筛选高残差点（前20%）
    high_residual_idx = torch.topk(prev_residuals.squeeze(), int(N*0.2))[1]
    high_residual_points = prev_points[high_residual_idx]
    
    # 2. 生成新采样点（80%）
    new_points, new_weights = sample_collocation_points(int(N*0.8))
    
    # 3. 合并自适应采样点（新点+高残差点）
    adaptive_points = torch.cat([new_points, high_residual_points], dim=0)
    # 补全权重（高残差点权重沿用之前的权重，或用1.0填充）
    high_residual_weights = prev_weights[high_residual_idx]  # 提取高残差点的原权重
    adaptive_weights = torch.cat([new_weights, high_residual_weights], dim=0)    
    return adaptive_points, adaptive_weights

def sample_initial_condition(N):
    """采样初始条件点（τ=0, x,y∈设计域）+ 面积元权重"""
    # 时间τ=0，归一化后为0
    tau_norm = np.zeros((N, 1))

    # 环形域（x,y）采样（同配点采样逻辑）
    r = np.random.uniform(r0, r1, size=(N, 1))
    theta = np.random.uniform(0.0, 2*np.pi, size=(N, 1))
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    x_norm = x / r1
    y_norm = y / r1

    # 面积元权重：环形域dA=r*dr*dθ，假设dr/dθ均匀，权重≈r（归一化后）
    weight = r / np.mean(r)

    points = np.hstack([x_norm, y_norm, tau_norm])
    return (torch.tensor(points, dtype=torch.float32).to(device),
            torch.tensor(weight, dtype=torch.float32).to(device))  # 返回（初始点，权重）

def sample_boundary(N1, N2):
    """采样边界点：N1=内管壁（Dirichlet），N2=外壳（Neumann），对应思路4.3"""
    # 1. 内管壁（x²+y²=r0²）
    theta1 = np.random.uniform(0.0, 2*np.pi, size=(N1, 1))
    x1 = r0 * np.cos(theta1)
    y1 = r0 * np.sin(theta1)
    x1_norm = x1 / r1
    y1_norm = y1 / r1
    tau1_norm = np.random.uniform(0.0, 1.0, size=(N1, 1))  # 时间∈[0,1]（归一化后）
    bc1_points = np.hstack([x1_norm, y1_norm, tau1_norm])

    # 2. 外壳（x²+y²=r1²）
    theta2 = np.random.uniform(0.0, 2*np.pi, size=(N2, 1))
    x2 = r1 * np.cos(theta2)
    y2 = r1 * np.sin(theta2)
    x2_norm = x2 / r1
    y2_norm = y2 / r1
    tau2_norm = np.random.uniform(0.0, 1.0, size=(N2, 1))
    bc2_points = np.hstack([x2_norm, y2_norm, tau2_norm])

    return (torch.tensor(bc1_points, dtype=torch.float32).to(device),
            torch.tensor(bc2_points, dtype=torch.float32).to(device))

# %%
def compute_loss(model, collocation_points, collocation_weights, ic_points, ic_weights, bc1_points, bc2_points, heat_storage=True):
    """
    计算总损失L_total = λ1*L_PDE + λ2*L_IC/BC + λ3*L_topo-constraint + λ4*L_objective
    heat_storage: True=储热过程，False=释热过程
    """
    # -------------------------- 1. 预处理：获取各类采样点的网络输出 --------------------------
    # 配点输出（用于PDE损失）
    model.train()
    x_col = collocation_points.requires_grad_(True)  # 需计算梯度，开启autograd
    ux_col, uy_col, p_col, T_col, phi_col, rho_x_col = model(x_col)
    rho_x_col = torch.clamp(rho_x_col, 1e-6, 1.0 - 1e-6)
    T_col = torch.clamp(T_col, 285.0, 365.0)  # 约束温度
    # 计算热物性参数
    rho_total, lambda_total, mu_total, nu_col, cp_total, a_col, S_t = compute_thermo_props(phi_col, rho_x_col, T_col)

    # 初始条件点输出（用于IC损失）
    x_ic = ic_points.requires_grad_(True)
    ux_ic, uy_ic, p_ic, T_ic, phi_ic, rho_x_ic = model(x_ic)

    # 边界点输出（用于BC损失）
    x_bc1 = bc1_points.requires_grad_(True)  # 内管壁（Dirichlet）
    ux_bc1, uy_bc1, p_bc1, T_bc1, phi_bc1, rho_x_bc1 = model(x_bc1)

    x_bc2 = bc2_points.requires_grad_(True)  # 外壳（Neumann）
    ux_bc2, uy_bc2, p_bc2, T_bc2, phi_bc2, rho_x_bc2 = model(x_bc2)

    # -------------------------- 2. PDE损失L_PDE--------------------------
    # 2.1 质量守恒损失L_mass
    # 自动微分计算∂ux/∂x, ∂uy/∂y
    grad_ux = torch.autograd.grad(ux_col, x_col, grad_outputs=torch.ones_like(ux_col),
                                  create_graph=True, retain_graph=True)[0]
    dudx = grad_ux[:, 0:1]  # ux对x的偏导
    dudy = grad_ux[:, 1:2]  # ux对y的偏导（无用，仅为了提取维度）

    grad_uy = torch.autograd.grad(uy_col, x_col, grad_outputs=torch.ones_like(uy_col),
                                  create_graph=True, retain_graph=True)[0]
    dvdy = grad_uy[:, 1:2]  # uy对y的偏导
    dvdx = grad_uy[:, 0:1]  # uy对x的偏导（无用）

    mass_residual = dudx + dvdy  # 质量守恒残差：∂ux/∂x + ∂uy/∂y
    L_mass = torch.sum(mass_residual ** 2 * collocation_weights) / torch.sum(collocation_weights)

    # 2.2 动量守恒损失L_momentum
    # 关键项计算：自动微分求一阶/二阶导数
    # 对流项：u·∇ux = ux*∂ux/∂x + uy*∂ux/∂y；u·∇uy = ux*∂uy/∂x + uy*∂uy/∂y
    convect_ux = ux_col * dudx + uy_col * dudy
    convect_uy = ux_col * dvdx + uy_col * dvdy

    # 压力梯度项：-1/ρ * ∂p/∂x；-1/ρ * ∂p/∂y
    grad_p = torch.autograd.grad(p_col, x_col, grad_outputs=torch.ones_like(p_col),
                                 create_graph=True, retain_graph=True)[0]
    dpdx = grad_p[:, 0:1]
    dpdy = grad_p[:, 1:2]
    pressure_term_x = -dpdx / rho_total
    pressure_term_y = -dpdy / rho_total

    # 粘性项：ν∇²ux = ν(∂²ux/∂x² + ∂²ux/∂y²)；ν∇²uy = ν(∂²uy/∂x² + ∂²uy/∂y²)
    # 二阶导数：对一阶导数再求导
    d2udx2 = torch.autograd.grad(dudx, x_col, grad_outputs=torch.ones_like(dudx),
                                 create_graph=True, retain_graph=True)[0][:, 0:1]
    d2udy2 = torch.autograd.grad(dudy, x_col, grad_outputs=torch.ones_like(dudy),
                                 create_graph=True, retain_graph=True)[0][:, 1:2]
    viscous_term_x = nu_col * (d2udx2 + d2udy2)

    d2vdx2 = torch.autograd.grad(dvdx, x_col, grad_outputs=torch.ones_like(dvdx),
                                 create_graph=True, retain_graph=True)[0][:, 0:1]
    d2vdy2 = torch.autograd.grad(dvdy, x_col, grad_outputs=torch.ones_like(dvdy),
                                 create_graph=True, retain_graph=True)[0][:, 1:2]
    viscous_term_y = nu_col * (d2vdx2 + d2vdy2)

    # 糊状区源项：-S_t*ux；-S_t*uy
    source_term_x = -S_t * ux_col
    source_term_y = -S_t * uy_col

    # 浮力项（仅y方向）：仅作用于液态PCM（铜占比rho_x_col，液态PCM占比(1-rho_x_col)*phi_col）
    F_B = rho_l * alpha * g * (T_col - Tpc) * (1.0 - rho_x_col) * phi_col

    # 动量残差（x,y方向）
    mom_residual_x = convect_ux - (pressure_term_x + viscous_term_x + source_term_x)
    mom_residual_y = convect_uy - (pressure_term_y + viscous_term_y + source_term_y + F_B)
    L_momentum = torch.sum((mom_residual_x ** 2 + mom_residual_y ** 2) * collocation_weights) / torch.sum(collocation_weights)

    # 2.3 传热控制损失L_heat（∂T/∂τ + u·∇T - a∇²T=0）
    # 一阶导数：∂T/∂x, ∂T/∂y, ∂T/∂τ（τ为归一化时间）
    grad_T = torch.autograd.grad(T_col, x_col, grad_outputs=torch.ones_like(T_col),
                             create_graph=True, retain_graph=True)[0]
    dTdx = grad_T[:, 0:1]
    dTdy = grad_T[:, 1:2]
    dTdtau_norm = grad_T[:, 2:3]  # 对归一化时间（τ_norm=τ/1e5）的导数

    # 时间导数量级转换：∂T/∂τ（实际时间）= ∂T/∂τ_norm * dτ_norm/dτ = dTdtau_norm / 1e5
    dTdtau_real = dTdtau_norm / 1e5

    # 对流项：u·∇T = ux*∂T/∂x + uy*∂T/∂y
    convect_T = ux_col * dTdx + uy_col * dTdy

    # 扩散项：a∇²T = a(∂²T/∂x² + ∂²T/∂y²)
    d2Tdx2 = torch.autograd.grad(dTdx, x_col, grad_outputs=torch.ones_like(dTdx),
                                 create_graph=True, retain_graph=True)[0][:, 0:1]
    d2Tdy2 = torch.autograd.grad(dTdy, x_col, grad_outputs=torch.ones_like(dTdy),
                                 create_graph=True, retain_graph=True)[0][:, 1:2]
    diffusive_term = a_col * (d2Tdx2 + d2Tdy2)

    # 传热残差（使用实际时间导数）
    heat_residual = dTdtau_real + convect_T - diffusive_term
    L_heat = torch.sum(heat_residual ** 2 * collocation_weights) / torch.sum(collocation_weights)

    # 2.4 液相率约束损失L_phi（φ∈[0,1]）
    L_phi = torch.sum((torch.max(torch.tensor(0.0).to(device), -phi_col) ** 2 +
                   torch.max(torch.tensor(0.0).to(device), phi_col - 1.0) ** 2) * collocation_weights) / torch.sum(collocation_weights)

    # 压力正则化：避免压力数值过大（小幅惩罚，不影响物理约束）
    L_pressure_reg = torch.mean(p_col ** 2) * 1e-6
    # PDE总损失
    L_PDE = L_mass + L_momentum + L_heat + L_phi + L_pressure_reg

    # -------------------------- 3. 初始/边界条件损失L_IC/BC--------------------------
    # 3.1 初始条件损失L_IC（τ=0）
    T0 = 290.0 if heat_storage else 360.0  # 储热T0=290K，释热T0=360K
    L_IC = torch.sum(((T_ic - T0) ** 2 * 10 + ux_ic ** 2 + uy_ic ** 2) * ic_weights) / torch.sum(ic_weights)

    # 3.2 边界条件损失L_BC
    # 内管壁（Dirichlet）：T=360K（储热）或290K（释热）
    Tw = 360.0 if heat_storage else 290.0
    L_BC1 = torch.mean((T_bc1 - Tw) ** 2 * 2)  # (T_bc1-Tw)²乘以2

    # 外壳（Neumann）：绝热，∂T/∂n=0（法向导数为0）
    grad_T_bc2 = torch.autograd.grad(T_bc2, x_bc2, grad_outputs=torch.ones_like(T_bc2), create_graph=True, retain_graph=True)[0]
    dTdx_bc2 = grad_T_bc2[:, 0:1]
    dTdy_bc2 = grad_T_bc2[:, 1:2]
    x_bc2_real = x_bc2[:, 0:1] * r1
    y_bc2_real = x_bc2[:, 1:2] * r1
    r_bc2 = r1  # 外壳边界的半径固定为r1，直接用常数
    dTdn = (x_bc2_real / r_bc2) * dTdx_bc2 + (y_bc2_real / r_bc2) * dTdy_bc2
    L_BC2 = torch.mean(dTdn**2)

    # IC/BC总损失
    L_IC_BC = L_IC + L_BC1 + L_BC2

    # -------------------------- 4. 拓扑约束损失L_topo-constraint--------------------------
    # 4.1 ρx取值约束（ρx∈[0,1]）
    L_rho_bounds = torch.sum((torch.max(torch.tensor(0.0).to(device), -rho_x_col) ** 2 +
                          torch.max(torch.tensor(0.0).to(device), rho_x_col - 1.0) ** 2) * collocation_weights) / torch.sum(collocation_weights)

    # 4.2 体积比约束（∫ρx dV ≤ φ_total∫dV）
    rho_x_avg = torch.sum(rho_x_col * collocation_weights) / torch.sum(collocation_weights)
    vol_residual = rho_x_avg - phi_total
    # 用logistic函数实现平滑软约束（10是约束强度，可调整）
    L_rho_vol = torch.log(1 + torch.exp(10 * vol_residual)) / 10

    # 拓扑约束总损失
    L_topo_constraint = L_rho_bounds + L_rho_vol

    # -------------------------- 5. 优化目标损失L_objective--------------------------
    # 采样优化目标点（设计域内）+ 面积元权重，开启自动求导
    x_obj, weight_obj = sample_collocation_points(N_obj)
    x_obj = x_obj.requires_grad_(True)
    ux_obj, uy_obj, p_obj, T_obj, phi_obj, rho_x_obj = model(x_obj)
    T_obj = torch.clamp(T_obj, 285.0, 365.0)  # 约束温度
    weight_obj = weight_obj.unsqueeze(1)  # [N_obj,1]，匹配张量维度

    # Case1：最小平均温度（加权平均）
    T_ave = torch.sum(T_obj * weight_obj) / torch.sum(weight_obj)
    L_obj1 = T_ave ** 2

    # Case2：最小温度均方差（加权均方差）
    T_var = torch.sum(((T_obj - T_ave) ** 2) * weight_obj) / torch.sum(weight_obj)
    L_obj2 = T_var

    # Case3：多目标（平均温度+温度均方差+火积耗散）
    # 火积耗散（φ_g=∫λ∇²T dA，加权积分）
    grad_T_obj = torch.autograd.grad(T_obj, x_obj, grad_outputs=torch.ones_like(T_obj),
                                     create_graph=True, retain_graph=True)[0]
    dTdx_obj = grad_T_obj[:, 0:1]
    dTdy_obj = grad_T_obj[:, 1:2]
    d2Tdx2_obj = torch.autograd.grad(dTdx_obj, x_obj, grad_outputs=torch.ones_like(dTdx_obj),
                                     create_graph=True, retain_graph=True)[0][:, 0:1]
    d2Tdy2_obj = torch.autograd.grad(dTdy_obj, x_obj, grad_outputs=torch.ones_like(dTdy_obj),
                                     create_graph=True, retain_graph=True)[0][:, 1:2]
    laplacian_T = torch.clamp(d2Tdx2_obj + d2Tdy2_obj, -1e3, 1e3)
    # 计算混合导热系数λ_total_obj
    rho_total_obj, lambda_total_obj, _, _, _, _, _ = compute_thermo_props(phi_obj, rho_x_obj, T_obj)
    phi_g = torch.sum(lambda_total_obj * laplacian_T * weight_obj) / torch.sum(weight_obj)
    L_obj3 = w1 * L_obj1 + w2 * L_obj2 + w3 * phi_g ** 2

    # 选择对应Case的目标损失
    if case == 1:
        L_objective = L_obj1
    elif case == 2:
        L_objective = L_obj2
    else:
        L_objective = L_obj3

    # -------------------------- 6. 总损失 --------------------------
    L_total = lambda1 * L_PDE + lambda2 * L_IC_BC + lambda3 * L_topo_constraint + lambda4 * L_objective

    # 返回各损失项（用于训练监控）
    return L_total, L_PDE, L_IC_BC, L_topo_constraint, L_objective

# %%
def train_model(model, epochs_pre=1000, epochs_fine=2000):
    """训练流程：预训练（满足物理约束）→ 精细优化（融合目标）"""
    #  优化器配置
    # 预训练：Adam优化器，快速降低物理约束损失
    optimizer_adam = optim.Adam(model.parameters(), lr=2e-4, weight_decay=1e-6)
    scheduler = CosineAnnealingLR(optimizer_adam, T_max=200, eta_min=1e-6)  # T_max=周期，eta_min=最小学习率

    # 精细优化：L-BFGS优化器，高精度梯度优化
    optimizer_lbfgs = optim.LBFGS(model.parameters(), lr=5e-4, max_iter=100, history_size=50)
    
    # 3. 预训练（仅优化物理约束+拓扑约束，屏蔽目标）
    print("="*50)
    print("开始预训练（满足物理约束）")
    print("="*50)
    global lambda4  # 临时修改目标损失权重为0
    lambda4_backup = lambda4
    lambda4 = 0.0

    # 预训练前初始化配点和权重
    collocation_points, collocation_weights = sample_collocation_points(N_mass)
    ic_points, ic_weights = sample_initial_condition(N_IC)
    bc1_points, bc2_points = sample_boundary(N_BC1, N_BC2)

    for epoch in range(epochs_pre):
        # 每50轮进行自适应采样（基于传热残差）
        if epoch % 50 == 0 and epoch != 0:
            # 步骤1：保存模型参数的requires_grad状态（后续恢复）
            param_requires_grad = {param: param.requires_grad for param in model.parameters()}
            # 步骤2：禁用模型参数的梯度（避免追踪参数梯度，但x_col_temp的梯度可以算）
            for param in model.parameters():
                param.requires_grad = False
        
            # 计算上一轮配点的传热残差（用于自适应采样）
            x_col_temp = collocation_points.requires_grad_(True)
            ux_col_temp, uy_col_temp, p_col_temp, T_col_temp, phi_col_temp, rho_x_col_temp = model(x_col_temp)
            rho_total_temp, lambda_total_temp, mu_total_temp, nu_col_temp, cp_total_temp, a_col_temp, S_t_temp = compute_thermo_props(phi_col_temp, rho_x_col_temp, T_col_temp)
            
            # 计算传热残差（仅需数值，临时保留计算图以计算二阶导数）
            grad_T_temp = torch.autograd.grad(
                T_col_temp, x_col_temp, 
                grad_outputs=torch.ones_like(T_col_temp),
                create_graph=True,       # 开启：让一阶导数可求二阶导
                retain_graph=True        # 保留：直到两个二阶导数都计算完成
            )[0]
            dTdx_temp = grad_T_temp[:, 0:1]
            dTdy_temp = grad_T_temp[:, 1:2]
            dTdtau_norm_temp = grad_T_temp[:, 2:3]
            dTdtau_real_temp = dTdtau_norm_temp / 1e5
            convect_T_temp = ux_col_temp * dTdx_temp + uy_col_temp * dTdy_temp
        
            # 计算二阶导数（先保留图，算完第二个再释放）
            d2Tdx2_temp = torch.autograd.grad(
                dTdx_temp, x_col_temp, 
                grad_outputs=torch.ones_like(dTdx_temp),
                create_graph=False,
                retain_graph=True        # 继续保留：给第二个二阶导数用
            )[0][:, 0:1]
            d2Tdy2_temp = torch.autograd.grad(
                dTdy_temp, x_col_temp, 
                grad_outputs=torch.ones_like(dTdy_temp),
                create_graph=False,
                retain_graph=False       # 释放：两个二阶导数都算完了
            )[0][:, 1:2]
        
            diffusive_term_temp = a_col_temp * (d2Tdx2_temp + d2Tdy2_temp)
            heat_residual_temp = dTdtau_real_temp + convect_T_temp - diffusive_term_temp
            # 手动释放计算图（彻底避免残留）
            T_col_temp.detach()
            x_col_temp.requires_grad_(False)  # 关闭x_col_temp的梯度
        
            # 步骤3：恢复模型参数的requires_grad状态（不影响后续训练）
            for param, req_grad in param_requires_grad.items():
                param.requires_grad = req_grad
        
            # 自适应采样更新配点和权重
            collocation_points, collocation_weights = adaptive_sample(model, N_mass, collocation_points, collocation_weights, heat_residual_temp)
            # 边界点和初始点固定更新（非自适应）
            bc1_points, bc2_points = sample_boundary(N_BC1, N_BC2)
            ic_points, ic_weights = sample_initial_condition(N_IC)
        # 计算损失（储热过程，可切换为释热）
        L_total, L_PDE, L_IC_BC, L_topo, L_obj = compute_loss(
            model, collocation_points, collocation_weights, ic_points, ic_weights, bc1_points, bc2_points, heat_storage=True
        )

        # 反向传播+参数更新
        L_total.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)  # 梯度裁剪防爆炸
        optimizer_adam.step()
        scheduler.step()

        # 每100轮打印损失
        if (epoch + 1) % 100 == 0:
            print(f"预训练Epoch [{epoch+1}/{epochs_pre}] | "
                  f"总损失: {L_total.item():.6f} | "
                  f"PDE损失: {L_PDE.item():.6f} | "
                  f"IC/BC损失: {L_IC_BC.item():.6f} | "
                  f"拓扑约束损失: {L_topo.item():.6f}")

    # 恢复目标损失权重
    lambda4 = lambda4_backup

    # 4. 精细优化（融合优化目标，用L-BFGS）
    print("\n" + "="*50)
    print("开始精细优化（融合优化目标）")
    print("="*50)

    def closure():
        """L-BFGS需要的闭包函数（重复计算损失和梯度）"""
        optimizer_lbfgs.zero_grad()
        L_total, L_PDE, L_IC_BC, L_topo, L_obj = compute_loss(
            model, collocation_points, collocation_weights, ic_points, ic_weights, bc1_points, bc2_points, heat_storage=True
        )
        L_total.backward()
        # 梯度裁剪：避免梯度爆炸，提升L-BFGS稳定性
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.1)
        return L_total

    for epoch in range(epochs_fine):
        optimizer_lbfgs.step(closure)
        # 计算当前损失用于打印
        L_total, L_PDE, L_IC_BC, L_topo, L_obj = compute_loss(
            model, collocation_points, collocation_weights, ic_points, ic_weights, bc1_points, bc2_points, heat_storage=True
        )

        # 每50轮打印损失
        if (epoch + 1) % 50 == 0:
            print(f"精细优化Epoch [{epoch+1}/{epochs_fine}] | "
                  f"总损失: {L_total.item():.6f} | "
                  f"PDE损失: {L_PDE.item():.6f} | "
                  f"目标损失: {L_obj.item():.6f} | "
                  f"体积比: {torch.mean(model(collocation_points)[5]).item():.3f}")

    # 5. 保存训练好的模型
    torch.save(model.state_dict(), f"topo_pinn_case{case}.pth")
    print("\n训练完成！模型已保存为 topo_pinn_case{case}.pth")

def compute_key_metrics(model, heat_storage=True):
    """
    计算论文关键指标，验证模型精度
    返回：完全熔化时间（φ=0.98）、平均储热容量、场协同角均值
    """
    # 1. 完全熔化时间计算（τ从0到1e5s，步长10s）
    complete_melting_time = None
    for tau in range(0, 100000, 10):
        tau_norm = tau / 1e5
        # 生成设计域配点
        collocation_points, collocation_weights = sample_collocation_points(5000)
        x = collocation_points.clone()
        x[:, 2:3] = torch.full_like(x[:, 2:3], tau_norm)
        _, _, _, _, phi, _ = model(x)
        phi_avg = torch.sum(phi * collocation_weights) / torch.sum(collocation_weights)  # 加权平均
        if phi_avg >= 0.98:
            complete_melting_time = tau
            break
    
    # 2. 平均储热容量计算（积分热流率/时间，τ=0到完全熔化时间）
    average_heat_storage = None
    if complete_melting_time is not None:
        heat_flux_list = []
        for tau in range(0, complete_melting_time, 50):
            tau_norm = tau / 1e5
            collocation_points, collocation_weights = sample_collocation_points(3000)  # 接收配点权重
            x = collocation_points.clone()
            x[:, 2:3] = torch.full_like(x[:, 2:3], tau_norm)
            x.requires_grad_(True)
            ux, uy, p, T, phi, rho_x = model(x)
            rho_total, lambda_total, _, _, _, a, _ = compute_thermo_props(phi, rho_x, T)
            # 计算热流密度q=-λ∇T（内管壁处）
            grad_T = torch.autograd.grad(T, x, grad_outputs=torch.ones_like(T), create_graph=True, retain_graph=True)[0]
            dTdr = (x[:, 0:1]*r1 * grad_T[:, 0:1] + x[:, 1:2]*r1 * grad_T[:, 1:2]) / (torch.sqrt((x[:, 0:1]*r1)**2 + (x[:, 1:2]*r1)**2) + 1e-10)
            q = -lambda_total * dTdr
            # 加权平均热流密度
            q_avg = torch.sum(q * collocation_weights) / torch.sum(collocation_weights)
            heat_flux_list.append(q_avg.item())
        average_heat_storage = np.mean(heat_flux_list)
    
    # 3. 场协同角均值（τ=200到1200s，传热对流主导阶段）
    field_synergy_angle_avg = None
    if complete_melting_time is not None and complete_melting_time > 1200:
        theta_list = []
        for tau in range(200, 1201, 100):
            tau_norm = tau / 1e5
            collocation_points, _ = sample_collocation_points(3000)
            x = collocation_points.clone()
            x[:, 2:3] = torch.full_like(x[:, 2:3], tau_norm)
            x.requires_grad_(True)
            ux, uy, p, T, phi, rho_x = model(x)
            # 计算u·∇T和||u||·||∇T||
            grad_T = torch.autograd.grad(T, x, grad_outputs=torch.ones_like(T), create_graph=True, retain_graph=True)[0]
            u_dot_gradT = ux * grad_T[:, 0:1] + uy * grad_T[:, 1:2]
            norm_u = torch.sqrt(ux**2 + uy**2 + 1e-10)
            norm_gradT = torch.sqrt(grad_T[:, 0:1]**2 + grad_T[:, 1:2]**2 + 1e-10)
            cos_theta = u_dot_gradT / (norm_u * norm_gradT)
            cos_theta = torch.clamp(cos_theta, -1.0, 1.0)  # 避免数值溢出
            theta = torch.acos(cos_theta) * (180 / np.pi)  # 弧度→角度
            theta_list.append(torch.mean(theta).item())
        field_synergy_angle_avg = np.mean(theta_list)
    
    return {
        "完全熔化时间(s)": complete_melting_time,
        "平均储热容量(W)": average_heat_storage,
        "场协同角均值(°)": field_synergy_angle_avg
    }

def visualize_results(model, save_path="./results"):
    """可视化结果：温度云图、液相率云图、拓扑结构（rho_x）"""
    import os
    os.makedirs(save_path, exist_ok=True)
    
    # 生成环形域网格点
    r = np.linspace(r0, r1, 100)
    theta = np.linspace(0, 2*np.pi, 100)
    R, Theta = np.meshgrid(r, theta)
    X = R * np.cos(Theta)
    Y = R * np.sin(Theta)
    
    # 选择关键时间点可视化（储热过程）
    tau_list = [100, 300, 500, 751, 1000]  # 751s为论文Case3完全熔化时间
    for tau in tau_list:
        tau_norm = tau / 1e5
        # 构造输入（x_norm, y_norm, tau_norm）
        x_input = np.hstack([
            X.reshape(-1, 1)/r1,
            Y.reshape(-1, 1)/r1,
            np.full((10000, 1), tau_norm)
        ])
        x_tensor = torch.tensor(x_input, dtype=torch.float32).to(device)
        ux, uy, p, T, phi, rho_x = model(x_tensor)
        
        # 转换为网格格式
        T_grid = T.detach().cpu().numpy().reshape(100, 100)
        phi_grid = phi.detach().cpu().numpy().reshape(100, 100)
        rho_x_grid = rho_x.detach().cpu().numpy().reshape(100, 100)
        
        # 绘制温度云图
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 3, 1)
        contourf = plt.contourf(X, Y, T_grid, cmap='jet', vmin=290, vmax=360)
        plt.colorbar(contourf, label='Temperature (K)')
        plt.title(f'Temperature (τ={tau}s)')
        plt.axis('equal')
        
        # 绘制液相率云图
        plt.subplot(1, 3, 2)
        contourf = plt.contourf(X, Y, phi_grid, cmap='viridis', vmin=0, vmax=1)
        plt.colorbar(contourf, label='Liquid Fraction φ')
        plt.title(f'Liquid Fraction (τ={tau}s)')
        plt.axis('equal')
        
        # 绘制拓扑结构（rho_x≥0.5为铜，否则为PCM）
        plt.subplot(1, 3, 3)
        contourf = plt.contourf(X, Y, (rho_x_grid >= 0.5).astype(int), cmap='binary')
        plt.colorbar(contourf, label='Topology (1=Cu, 0=PCM)')
        plt.title(f'Topological Structure (τ={tau}s)')
        plt.axis('equal')
        
        plt.tight_layout()
        plt.savefig(os.path.join(save_path, f'result_tau_{tau}s.png'), dpi=300, bbox_inches='tight')
        plt.close()
    
    print(f"可视化结果已保存到 {save_path}")

# -------------------------- 启动训练 --------------------------
if __name__ == "__main__":
    # 初始化模型（残差网络：6层隐藏层，256神经元）
    model = TopoPINN(input_dim=3, output_dim=6, hidden_layers=6, hidden_dim=256).to(device)
    # 启动训练（预训练20000轮，精细优化2000轮）
    train_model(model, epochs_pre=20000, epochs_fine=2000)
    
    # 加载训练好的模型（若训练中断可直接加载）
    model.load_state_dict(torch.load(f"topo_pinn_case{case}.pth"))
    model.eval()  # 切换为评估模式
    
    # 计算关键指标，与论文对比
    print("\n" + "="*50)
    print("关键指标验证（对标论文Case3）")
    print("="*50)
    metrics = compute_key_metrics(model, heat_storage=True)
    for key, value in metrics.items():
        if value is not None:
            print(f"{key}: {value:.2f}")
        else:
            print(f"{key}: 未计算成功")
    
    # 可视化结果（温度、液相率、拓扑结构）
    visualize_results(model, save_path="./topo_pinn_results")
    print("\n训练+验证+可视化完成！")
# Out:
# ==================================================
# 开始预训练（满足物理约束）
# ==================================================
# 预训练Epoch [100/20000] | 总损失: 6712812.000000 | PDE损失: 60.781071 | IC/BC损失: 443.468689 | 拓扑约束损失: 0.067849
# 预训练Epoch [200/20000] | 总损失: 4170061.500000 | PDE损失: 44.904320 | IC/BC损失: 275.010468 | 拓扑约束损失: 0.062262
# 预训练Epoch [300/20000] | 总损失: 3967185.750000 | PDE损失: 28.634111 | IC/BC损失: 262.570099 | 拓扑约束损失: 0.054100
# 预训练Epoch [400/20000] | 总损失: 7365635.000000 | PDE损失: 28.665079 | IC/BC损失: 489.131287 | 拓扑约束损失: 0.052716
# 预训练Epoch [500/20000] | 总损失: 5632128.500000 | PDE损失: 23.996792 | IC/BC损失: 373.875397 | 拓扑约束损失: 0.051997
# 预训练Epoch [600/20000] | 总损失: 2719604.000000 | PDE损失: 18.854956 | IC/BC损失: 180.049911 | 拓扑约束损失: 0.050698
# 预训练Epoch [700/20000] | 总损失: 4278986.000000 | PDE损失: 17.164202 | IC/BC损失: 284.121460 | 拓扑约束损失: 0.046173
# 预训练Epoch [800/20000] | 总损失: 8536921.000000 | PDE损失: 19.581758 | IC/BC损失: 567.822632 | 拓扑约束损失: 0.045100
# 预训练Epoch [900/20000] | 总损失: 3778899.750000 | PDE损失: 15.483843 | IC/BC损失: 250.894379 | 拓扑约束损失: 0.044551
# 预训练Epoch [1000/20000] | 总损失: 2906366.500000 | PDE损失: 14.109881 | IC/BC损失: 192.817078 | 拓扑约束损失: 0.041723
# 预训练Epoch [1100/20000] | 总损失: 2556399.750000 | PDE损失: 12.727559 | IC/BC损失: 169.578140 | 拓扑约束损失: 0.037850
# 预训练Epoch [1200/20000] | 总损失: 6501952.000000 | PDE损失: 17.588696 | IC/BC损失: 432.290894 | 拓扑约束损失: 0.039245
# 预训练Epoch [1300/20000] | 总损失: 4409564.500000 | PDE损失: 13.934533 | IC/BC损失: 293.041992 | 拓扑约束损失: 0.034982
# 预训练Epoch [1400/20000] | 总损失: 1487557.625000 | PDE损失: 10.394096 | IC/BC损失: 98.477562 | 拓扑约束损失: 0.032430
# 预训练Epoch [1500/20000] | 总损失: 2436442.750000 | PDE损失: 9.176785 | IC/BC损失: 161.817719 | 拓扑约束损失: 0.029116
# 预训练Epoch [1600/20000] | 总损失: 5184081.000000 | PDE损失: 24.758112 | IC/BC损失: 343.954865 | 拓扑约束损失: 0.033972
# 预训练Epoch [1700/20000] | 总损失: 3646658.500000 | PDE损失: 71.727814 | IC/BC损失: 238.328720 | 拓扑约束损失: 0.015326
# 预训练Epoch [1800/20000] | 总损失: 1612605.750000 | PDE损失: 7.210760 | IC/BC损失: 107.026329 | 拓扑约束损失: 0.013088
# 预训练Epoch [1900/20000] | 总损失: 3038058.000000 | PDE损失: 5.983189 | IC/BC损失: 202.138321 | 拓扑约束损失: 0.012039
# 预训练Epoch [2000/20000] | 总损失: 3810821.250000 | PDE损失: 6.902815 | IC/BC损失: 253.594559 | 拓扑约束损失: 0.014570
# 预训练Epoch [2100/20000] | 总损失: 1483892.125000 | PDE损失: 7.912381 | IC/BC损失: 98.398651 | 拓扑约束损失: 0.010766
# 预训练Epoch [2200/20000] | 总损失: 778490.062500 | PDE损失: 5.800269 | IC/BC损失: 51.512650 | 拓扑约束损失: 0.009643
# 预训练Epoch [2300/20000] | 总损失: 2077356.750000 | PDE损失: 5.564588 | IC/BC损失: 138.119476 | 拓扑约束损失: 0.009753
# 预训练Epoch [2400/20000] | 总损失: 1650894.500000 | PDE损失: 85.484940 | IC/BC损失: 104.360634 | 拓扑约束损失: 0.006138
# 预训练Epoch [2500/20000] | 总损失: 1650385.500000 | PDE损失: 51.776840 | IC/BC损失: 106.573906 | 拓扑约束损失: 0.005840
# 预训练Epoch [2600/20000] | 总损失: 642114.750000 | PDE损失: 4.652256 | IC/BC损失: 42.497501 | 拓扑约束损失: 0.005756
# 预训练Epoch [2700/20000] | 总损失: 3029472.750000 | PDE损失: 6.921978 | IC/BC损失: 201.503387 | 拓扑约束损失: 0.005808
# 预训练Epoch [2800/20000] | 总损失: 2152079.000000 | PDE损失: 34.795609 | IC/BC损失: 141.152237 | 拓扑约束损失: 0.005623
# 预训练Epoch [2900/20000] | 总损失: 753531.125000 | PDE损失: 8.459962 | IC/BC损失: 49.671413 | 拓扑约束损失: 0.005313
# 预训练Epoch [3000/20000] | 总损失: 603884.437500 | PDE损失: 3.543678 | IC/BC损失: 40.022717 | 拓扑约束损失: 0.005237
# 预训练Epoch [3100/20000] | 总损失: 692622.750000 | PDE损失: 4.304408 | IC/BC损失: 45.887886 | 拓扑约束损失: 0.005315
# 预训练Epoch [3200/20000] | 总损失: 2629153.750000 | PDE损失: 105.551926 | IC/BC损失: 168.240112 | 拓扑约束损失: 0.006020
# 预训练Epoch [3300/20000] | 总损失: 919062.312500 | PDE损失: 7.075475 | IC/BC损失: 60.799122 | 拓扑约束损失: 0.005206
# 预训练Epoch [3400/20000] | 总损失: 587213.000000 | PDE损失: 1.311535 | IC/BC损失: 39.060097 | 拓扑约束损失: 0.005112
# 预训练Epoch [3500/20000] | 总损失: 5237150.500000 | PDE损失: 2.767001 | IC/BC损失: 348.958893 | 拓扑约束损失: 0.005123
# 预训练Epoch [3600/20000] | 总损失: 2434972.000000 | PDE损失: 249.991028 | IC/BC损失: 145.665405 | 拓扑约束损失: 0.005744
# 预训练Epoch [3700/20000] | 总损失: 1344165.625000 | PDE损失: 9.625575 | IC/BC损失: 88.969337 | 拓扑约束损失: 0.005176
# 预训练Epoch [3800/20000] | 总损失: 490582.343750 | PDE损失: 1.389731 | IC/BC损失: 32.612839 | 拓扑约束损失: 0.005132
# 预训练Epoch [3900/20000] | 总损失: 640518.500000 | PDE损失: 5.389618 | IC/BC损失: 42.341927 | 拓扑约束损失: 0.005149
# 预训练Epoch [4000/20000] | 总损失: 932850.062500 | PDE损失: 31.026659 | IC/BC损失: 60.121559 | 拓扑约束损失: 0.005108
# 预训练Epoch [4100/20000] | 总损失: 522686.656250 | PDE损失: 5.883067 | IC/BC损失: 34.453571 | 拓扑约束损失: 0.005158
# 预训练Epoch [4200/20000] | 总损失: 583790.625000 | PDE损失: 1.488790 | IC/BC损失: 38.820122 | 拓扑约束损失: 0.005118
# 预训练Epoch [4300/20000] | 总损失: 274456.718750 | PDE损失: 2.456446 | IC/BC损失: 18.133350 | 拓扑约束损失: 0.005101
# 预训练Epoch [4400/20000] | 总损失: 1217991.375000 | PDE损失: 8.582293 | IC/BC损失: 80.627274 | 拓扑约束损失: 0.005152
# 预训练Epoch [4500/20000] | 总损失: 3114755.750000 | PDE损失: 3.436760 | IC/BC损失: 207.421265 | 拓扑约束损失: 0.005126
# 预训练Epoch [4600/20000] | 总损失: 294905.218750 | PDE损失: 1.497634 | IC/BC损失: 19.560505 | 拓扑约束损失: 0.005088
# 预训练Epoch [4700/20000] | 总损失: 573405.625000 | PDE损失: 1.324049 | IC/BC损失: 38.138771 | 拓扑约束损失: 0.005052
# 预训练Epoch [4800/20000] | 总损失: 6061164.000000 | PDE损失: 10.774752 | IC/BC损失: 403.359253 | 拓扑约束损失: 0.005166
# 预训练Epoch [4900/20000] | 总损失: 1134632.375000 | PDE损失: 7.063951 | IC/BC损失: 75.171227 | 拓扑约束损失: 0.005090
# 预训练Epoch [5000/20000] | 总损失: 548997.187500 | PDE损失: 1.504338 | IC/BC损失: 36.499523 | 拓扑约束损失: 0.005031
# 预训练Epoch [5100/20000] | 总损失: 413294.437500 | PDE损失: 1.169088 | IC/BC损失: 27.475021 | 拓扑约束损失: 0.005008
# 预训练Epoch [5200/20000] | 总损失: 768334.187500 | PDE损失: 17.403812 | IC/BC损失: 50.062023 | 拓扑约束损失: 0.005074
# 预训练Epoch [5300/20000] | 总损失: 756647.437500 | PDE损失: 4.156717 | IC/BC损失: 50.166050 | 拓扑约束损失: 0.005008
# 预训练Epoch [5400/20000] | 总损失: 165895.718750 | PDE损失: 1.158608 | IC/BC损失: 10.982471 | 拓扑约束损失: 0.004989
# 预训练Epoch [5500/20000] | 总损失: 783415.812500 | PDE损失: 2.323740 | IC/BC损失: 52.072803 | 拓扑约束损失: 0.004975
# 预训练Epoch [5600/20000] | 总损失: 593912.812500 | PDE损失: 50.955864 | IC/BC损失: 36.197128 | 拓扑约束损失: 0.004954
# 预训练Epoch [5700/20000] | 总损失: 724680.562500 | PDE损失: 22.225170 | IC/BC损失: 46.830357 | 拓扑约束损失: 0.005028
# 预训练Epoch [5800/20000] | 总损失: 283300.781250 | PDE损失: 2.667507 | IC/BC损失: 18.708883 | 拓扑约束损失: 0.004972
# 预训练Epoch [5900/20000] | 总损失: 276953.812500 | PDE损失: 2.603158 | IC/BC损失: 18.290041 | 拓扑约束损失: 0.004950
# 预训练Epoch [6000/20000] | 总损失: 37419664.000000 | PDE损失: 21.316845 | IC/BC损失: 2493.223145 | 拓扑约束损失: 0.004958
# 预训练Epoch [6100/20000] | 总损失: 306261.781250 | PDE损失: 1.435292 | IC/BC损失: 20.321764 | 拓扑约束损失: 0.004929
# 预训练Epoch [6200/20000] | 总损失: 195836.968750 | PDE损失: 0.767989 | IC/BC损失: 13.004597 | 拓扑约束损失: 0.004921
# 预训练Epoch [6300/20000] | 总损失: 205004.296875 | PDE损失: 0.999751 | IC/BC损失: 13.600301 | 拓扑约束损失: 0.004910
# 预训练Epoch [6400/20000] | 总损失: 1753049.250000 | PDE损失: 66.988808 | IC/BC损失: 112.404037 | 拓扑约束损失: 0.004983
# 预训练Epoch [6500/20000] | 总损失: 594882.937500 | PDE损失: 3.504253 | IC/BC损失: 39.425247 | 拓扑约束损失: 0.004975
# 预训练Epoch [6600/20000] | 总损失: 204865.968750 | PDE损失: 1.277392 | IC/BC损失: 13.572570 | 拓扑约束损失: 0.004943
# 预训练Epoch [6700/20000] | 总损失: 244379.625000 | PDE损失: 0.865036 | IC/BC损失: 16.234304 | 拓扑约束损失: 0.004923
# 预训练Epoch [6800/20000] | 总损失: 2582740.750000 | PDE损失: 14.474589 | IC/BC损失: 171.217743 | 拓扑约束损失: 0.005057
# 预训练Epoch [6900/20000] | 总损失: 461275.437500 | PDE损失: 1.018112 | IC/BC损失: 30.683819 | 拓扑约束损失: 0.004920
# 预训练Epoch [7000/20000] | 总损失: 137971.218750 | PDE损失: 0.636107 | IC/BC损失: 9.155672 | 拓扑约束损失: 0.004913
# 预训练Epoch [7100/20000] | 总损失: 3137638.750000 | PDE损失: 0.570167 | IC/BC损失: 209.137894 | 拓扑约束损失: 0.004906
# 预训练Epoch [7200/20000] | 总损失: 3448407.000000 | PDE损失: 1.553492 | IC/BC损失: 229.790237 | 拓扑约束损失: 0.004910
# 预训练Epoch [7300/20000] | 总损失: 14357126.000000 | PDE损失: 1.095177 | IC/BC损失: 957.068726 | 拓扑约束损失: 0.004906
# 预训练Epoch [7400/20000] | 总损失: 130637.625000 | PDE损失: 0.608639 | IC/BC损失: 8.668597 | 拓扑约束损失: 0.004903
# 预训练Epoch [7500/20000] | 总损失: 238890.421875 | PDE损失: 0.839308 | IC/BC损失: 15.870072 | 拓扑约束损失: 0.004897
# 预训练Epoch [7600/20000] | 总损失: 76895336.000000 | PDE损失: 0.783030 | IC/BC损失: 5126.303223 | 拓扑约束损失: 0.004897
# 预训练Epoch [7700/20000] | 总损失: 1253868.375000 | PDE损失: 1.755523 | IC/BC损失: 83.474190 | 拓扑约束损失: 0.004898
# 预训练Epoch [7800/20000] | 总损失: 167081.171875 | PDE损失: 0.429388 | IC/BC损失: 11.110117 | 拓扑约束损失: 0.004898
# 预训练Epoch [7900/20000] | 总损失: 11240760.000000 | PDE损失: 0.669567 | IC/BC损失: 749.339355 | 拓扑约束损失: 0.004892
# 预训练Epoch [8000/20000] | 总损失: 596670.625000 | PDE损失: 26.889181 | IC/BC损失: 37.985428 | 拓扑约束损失: 0.004929
# 预训练Epoch [8100/20000] | 总损失: 394241.593750 | PDE损失: 3.840532 | IC/BC损失: 26.026735 | 拓扑约束损失: 0.004909
# 预训练Epoch [8200/20000] | 总损失: 244463.531250 | PDE损失: 0.812290 | IC/BC损失: 16.243414 | 拓扑约束损失: 0.004897
# 预训练Epoch [8300/20000] | 总损失: 6064166.500000 | PDE损失: 0.687940 | IC/BC损失: 404.231903 | 拓扑约束损失: 0.004885
# 预训练Epoch [8400/20000] | 总损失: 383362.968750 | PDE损失: 35.479370 | IC/BC损失: 23.192238 | 拓扑约束损失: 0.004903
# 预训练Epoch [8500/20000] | 总损失: 157198.109375 | PDE损失: 7.641815 | IC/BC损失: 9.970418 | 拓扑约束损失: 0.004898
# 预训练Epoch [8600/20000] | 总损失: 103796.945312 | PDE损失: 0.362111 | IC/BC损失: 6.895654 | 拓扑约束损失: 0.004892
# 预训练Epoch [8700/20000] | 总损失: 307004.812500 | PDE损失: 1.141640 | IC/BC损失: 20.390877 | 拓扑约束损失: 0.004886
# 预训练Epoch [8800/20000] | 总损失: 1193811.625000 | PDE损失: 8.684274 | IC/BC损失: 79.008492 | 拓扑约束损失: 0.004966
# 预训练Epoch [8900/20000] | 总损失: 383480.656250 | PDE损失: 1.528749 | IC/BC损失: 25.463459 | 拓扑约束损失: 0.004911
# 预训练Epoch [9000/20000] | 总损失: 123342.593750 | PDE损失: 0.548578 | IC/BC损失: 8.186266 | 拓扑约束损失: 0.004901
# 预训练Epoch [9100/20000] | 总损失: 153940.359375 | PDE损失: 1.168586 | IC/BC损失: 10.184782 | 拓扑约束损失: 0.004894
# 预训练Epoch [9200/20000] | 总损失: 3363653.250000 | PDE损失: 3.140982 | IC/BC损失: 224.034149 | 拓扑约束损失: 0.004927
# 预训练Epoch [9300/20000] | 总损失: 1135061.500000 | PDE损失: 1.306041 | IC/BC损失: 75.583702 | 拓扑约束损失: 0.004941
# 预训练Epoch [9400/20000] | 总损失: 8932.510742 | PDE损失: 0.739561 | IC/BC损失: 0.546195 | 拓扑约束损失: 0.004906
# 预训练Epoch [9500/20000] | 总损失: 8679090.000000 | PDE损失: 0.609288 | IC/BC损失: 578.565430 | 拓扑约束损失: 0.004896
# 预训练Epoch [9600/20000] | 总损失: 1692935.750000 | PDE损失: 10.187497 | IC/BC损失: 112.183220 | 拓扑约束损失: 0.004906
# 预训练Epoch [9700/20000] | 总损失: 145869.453125 | PDE损失: 1.048698 | IC/BC损失: 9.654715 | 拓扑约束损失: 0.004915
# 预训练Epoch [9800/20000] | 总损失: 103307.500000 | PDE损失: 0.751395 | IC/BC损失: 6.837072 | 拓扑约束损失: 0.004910
# 预训练Epoch [9900/20000] | 总损失: 1436894.125000 | PDE损失: 2.410766 | IC/BC损失: 95.632225 | 拓扑约束损失: 0.004903
# 预训练Epoch [10000/20000] | 总损失: 1226009.875000 | PDE损失: 31.238638 | IC/BC损失: 79.651413 | 拓扑约束损失: 0.004899
# 预训练Epoch [10100/20000] | 总损失: 595477.812500 | PDE损失: 4.775673 | IC/BC损失: 39.380142 | 拓扑约束损失: 0.004891
# 预训练Epoch [10200/20000] | 总损失: 123987.515625 | PDE损失: 1.212703 | IC/BC损失: 8.184986 | 拓扑约束损失: 0.004891
# 预训练Epoch [10300/20000] | 总损失: 18172176.000000 | PDE损失: 0.355440 | IC/BC损失: 1211.454712 | 拓扑约束损失: 0.004883
# 预训练Epoch [10400/20000] | 总损失: 179336.312500 | PDE损失: 5.174789 | IC/BC损失: 11.610765 | 拓扑约束损失: 0.004891
# 预训练Epoch [10500/20000] | 总损失: 2428473.500000 | PDE损失: 1.491834 | IC/BC损失: 161.798782 | 拓扑约束损失: 0.004881
# 预训练Epoch [10600/20000] | 总损失: 45732.250000 | PDE损失: 0.500782 | IC/BC损失: 3.015430 | 拓扑约束损失: 0.004879
# 预训练Epoch [10700/20000] | 总损失: 898311.875000 | PDE损失: 1.778834 | IC/BC损失: 59.768871 | 拓扑约束损失: 0.004878
# 预训练Epoch [10800/20000] | 总损失: 487803.906250 | PDE损失: 0.801759 | IC/BC损失: 32.466808 | 拓扑约束损失: 0.004880
# 预训练Epoch [10900/20000] | 总损失: 412144.250000 | PDE损失: 0.809765 | IC/BC损失: 27.422298 | 拓扑约束损失: 0.004874
# 预训练Epoch [11000/20000] | 总损失: 76666.039062 | PDE损失: 0.397733 | IC/BC损失: 5.084552 | 拓扑约束损失: 0.004873
# 预训练Epoch [11100/20000] | 总损失: 425398.656250 | PDE损失: 1.293819 | IC/BC损失: 28.273655 | 拓扑约束损失: 0.004872
# 预训练Epoch [11200/20000] | 总损失: 200895.937500 | PDE损失: 1.824204 | IC/BC损失: 13.271447 | 拓扑约束损失: 0.004879
# 预训练Epoch [11300/20000] | 总损失: 306690.093750 | PDE损失: 1.292832 | IC/BC损失: 20.359816 | 拓扑约束损失: 0.004869
# 预训练Epoch [11400/20000] | 总损失: 6640.381836 | PDE损失: 0.548019 | IC/BC损失: 0.406156 | 拓扑约束损失: 0.004870
# 预训练Epoch [11500/20000] | 总损失: 20966888.000000 | PDE损失: 0.396543 | IC/BC损失: 1397.766113 | 拓扑约束损失: 0.004870
# 预训练Epoch [11600/20000] | 总损失: 403771.312500 | PDE损失: 1.483763 | IC/BC损失: 26.819168 | 拓扑约束损失: 0.004884
# 预训练Epoch [11700/20000] | 总损失: 349984.687500 | PDE损失: 10.199372 | IC/BC损失: 22.652351 | 拓扑约束损失: 0.004876
# 预训练Epoch [11800/20000] | 总损失: 241258.031250 | PDE损失: 0.639125 | IC/BC损失: 16.041258 | 拓扑约束损失: 0.004876
# 预训练Epoch [11900/20000] | 总损失: 72389.898438 | PDE损失: 1.278039 | IC/BC损失: 4.740789 | 拓扑约束损失: 0.004870
# 预训练Epoch [12000/20000] | 总损失: 372662.812500 | PDE损失: 12.671752 | IC/BC损失: 23.999401 | 拓扑约束损失: 0.004874
# 预训练Epoch [12100/20000] | 总损失: 141926.750000 | PDE损失: 58.393906 | IC/BC损失: 5.568854 | 拓扑约束损失: 0.004876
# 预训练Epoch [12200/20000] | 总损失: 41689.898438 | PDE损失: 0.394564 | IC/BC损失: 2.753021 | 拓扑约束损失: 0.004878
# 预训练Epoch [12300/20000] | 总损失: 254974.484375 | PDE损失: 0.722270 | IC/BC损失: 16.950146 | 拓扑约束损失: 0.004873
# 预训练Epoch [12400/20000] | 总损失: 670547.000000 | PDE损失: 12.261668 | IC/BC损失: 43.885689 | 拓扑约束损失: 0.004946
# 预训练Epoch [12500/20000] | 总损失: 332538.687500 | PDE损失: 1.092003 | IC/BC损失: 22.096443 | 拓扑约束损失: 0.004878
# 预训练Epoch [12600/20000] | 总损失: 96423.445312 | PDE损失: 0.789065 | IC/BC损失: 6.375624 | 拓扑约束损失: 0.004877
# 预训练Epoch [12700/20000] | 总损失: 15035.262695 | PDE损失: 0.721588 | IC/BC损失: 0.954243 | 拓扑约束损失: 0.004876
# 预训练Epoch [12800/20000] | 总损失: 320284.968750 | PDE损失: 4.215612 | IC/BC损失: 21.071287 | 拓扑约束损失: 0.004877
# 预训练Epoch [12900/20000] | 总损失: 176826.875000 | PDE损失: 4.524042 | IC/BC损失: 11.486853 | 拓扑约束损失: 0.004885
# 预训练Epoch [13000/20000] | 总损失: 63157.289062 | PDE损失: 0.507526 | IC/BC损失: 4.176649 | 拓扑约束损失: 0.004880
# 预训练Epoch [13100/20000] | 总损失: 199854.046875 | PDE损失: 0.504640 | IC/BC损失: 13.289958 | 拓扑约束损失: 0.004875
# 预训练Epoch [13200/20000] | 总损失: 594125.000000 | PDE损失: 0.848349 | IC/BC损失: 39.551773 | 拓扑约束损失: 0.004873
# 预训练Epoch [13300/20000] | 总损失: 59829.511719 | PDE损失: 0.640050 | IC/BC损失: 3.945962 | 拓扑约束损失: 0.004871
# 预训练Epoch [13400/20000] | 总损失: 66184.132812 | PDE损失: 0.208241 | IC/BC损失: 4.398391 | 拓扑约束损失: 0.004869
# 预训练Epoch [13500/20000] | 总损失: 119157.843750 | PDE损失: 1.852032 | IC/BC损失: 7.820386 | 拓扑约束损失: 0.004868
# 预训练Epoch [13600/20000] | 总损失: 402879.250000 | PDE损失: 2.000372 | IC/BC损失: 26.725256 | 拓扑约束损失: 0.004870
# 预训练Epoch [13700/20000] | 总损失: 1953267.125000 | PDE损失: 8.732150 | IC/BC损失: 129.635666 | 拓扑约束损失: 0.004875
# 预训练Epoch [13800/20000] | 总损失: 63454.531250 | PDE损失: 0.270475 | IC/BC损失: 4.212269 | 拓扑约束损失: 0.004873
# 预训练Epoch [13900/20000] | 总损失: 134091.328125 | PDE损失: 0.257469 | IC/BC损失: 8.922256 | 拓扑约束损失: 0.004871
# 预训练Epoch [14000/20000] | 总损失: 358674.906250 | PDE损失: 1.281826 | IC/BC损失: 23.826204 | 拓扑约束损失: 0.004874
# 预训练Epoch [14100/20000] | 总损失: 373110.968750 | PDE损失: 0.474795 | IC/BC损失: 24.842411 | 拓扑约束损失: 0.004873
# 预训练Epoch [14200/20000] | 总损失: 99213.343750 | PDE损失: 0.257101 | IC/BC损失: 6.597081 | 拓扑约束损失: 0.004873
# 预训练Epoch [14300/20000] | 总损失: 199331.593750 | PDE损失: 0.273076 | IC/BC损失: 13.270566 | 拓扑约束损失: 0.004870
# 预训练Epoch [14400/20000] | 总损失: 536160.250000 | PDE损失: 0.684272 | IC/BC损失: 35.698399 | 拓扑约束损失: 0.004870
# 预训练Epoch [14500/20000] | 总损失: 175202.703125 | PDE损失: 1.663786 | IC/BC损失: 11.569260 | 拓扑约束损失: 0.004868
# 预训练Epoch [14600/20000] | 总损失: 65723.257812 | PDE损失: 1.014403 | IC/BC损失: 4.313922 | 拓扑约束损失: 0.004865
# 预训练Epoch [14700/20000] | 总损失: 681189.750000 | PDE损失: 0.868813 | IC/BC损失: 45.354729 | 拓扑约束损失: 0.004864
# 预训练Epoch [14800/20000] | 总损失: 421129.812500 | PDE损失: 1.942197 | IC/BC损失: 27.945839 | 拓扑约束损失: 0.004873
# 预训练Epoch [14900/20000] | 总损失: 1529208.000000 | PDE损失: 1.319584 | IC/BC损失: 101.859222 | 拓扑约束损失: 0.004871
# 预训练Epoch [15000/20000] | 总损失: 42313.351562 | PDE损失: 0.180512 | IC/BC损失: 2.808854 | 拓扑约束损失: 0.004873
# 预训练Epoch [15100/20000] | 总损失: 1610059.500000 | PDE损失: 0.320222 | IC/BC损失: 107.315948 | 拓扑约束损失: 0.004872
# 预训练Epoch [15200/20000] | 总损失: 271729.125000 | PDE损失: 0.983817 | IC/BC损失: 18.049685 | 拓扑约束损失: 0.004879
# 预训练Epoch [15300/20000] | 总损失: 69217.046875 | PDE损失: 0.398229 | IC/BC损失: 4.587920 | 拓扑约束损失: 0.004880
# 预训练Epoch [15400/20000] | 总损失: 1908.343750 | PDE损失: 0.178303 | IC/BC损失: 0.115334 | 拓扑约束损失: 0.004878
# 预训练Epoch [15500/20000] | 总损失: 2227827.750000 | PDE损失: 0.269516 | IC/BC损失: 148.503891 | 拓扑约束损失: 0.004874
# 预训练Epoch [15600/20000] | 总损失: 745363.437500 | PDE损失: 1.113826 | IC/BC损失: 49.616642 | 拓扑约束损失: 0.004877
# 预训练Epoch [15700/20000] | 总损失: 219664.140625 | PDE损失: 0.460303 | IC/BC损失: 14.613587 | 拓扑约束损失: 0.004877
# 预训练Epoch [15800/20000] | 总损失: 36621.496094 | PDE损失: 0.183491 | IC/BC损失: 2.429199 | 拓扑约束损失: 0.004877
# 预训练Epoch [15900/20000] | 总损失: 115211.031250 | PDE损失: 0.283970 | IC/BC损失: 7.661803 | 拓扑约束损失: 0.004874
# 预训练Epoch [16000/20000] | 总损失: 1035936.625000 | PDE损失: 54.109337 | IC/BC损失: 65.455154 | 拓扑约束损失: 0.004867
# 预训练Epoch [16100/20000] | 总损失: 105812.296875 | PDE损失: 0.200808 | IC/BC损失: 7.040764 | 拓扑约束损失: 0.004878
# 预训练Epoch [16200/20000] | 总损失: 98396.804688 | PDE损失: 0.170418 | IC/BC损失: 6.548424 | 拓扑约束损失: 0.004875
# 预训练Epoch [16300/20000] | 总损失: 24573.224609 | PDE损失: 0.123743 | IC/BC损失: 1.629964 | 拓扑约束损失: 0.004876
# 预训练Epoch [16400/20000] | 总损失: 109485.187500 | PDE损失: 0.590862 | IC/BC损失: 7.259620 | 拓扑约束损失: 0.004870
# 预训练Epoch [16500/20000] | 总损失: 116166.335938 | PDE损失: 0.413182 | IC/BC损失: 7.716876 | 拓扑约束损失: 0.004877
# 预训练Epoch [16600/20000] | 总损失: 39949.226562 | PDE损失: 0.235105 | IC/BC损失: 2.647607 | 拓扑约束损失: 0.004875
# 预训练Epoch [16700/20000] | 总损失: 3517736.500000 | PDE损失: 1.058169 | IC/BC损失: 234.445221 | 拓扑约束损失: 0.004868
# 预训练Epoch [16800/20000] | 总损失: 377524.781250 | PDE损失: 1.366941 | IC/BC损失: 25.077187 | 拓扑约束损失: 0.004887
# 预训练Epoch [16900/20000] | 总损失: 81945.132812 | PDE损失: 0.781587 | IC/BC损失: 5.410902 | 拓扑约束损失: 0.004873
# 预训练Epoch [17000/20000] | 总损失: 112677.031250 | PDE损失: 0.220109 | IC/BC损失: 7.497127 | 拓扑约束损失: 0.004869
# 预训练Epoch [17100/20000] | 总损失: 349309.562500 | PDE损失: 0.369048 | IC/BC损失: 23.262697 | 拓扑约束损失: 0.004867
# 预训练Epoch [17200/20000] | 总损失: 676237.937500 | PDE损失: 0.610755 | IC/BC损失: 45.041813 | 拓扑约束损失: 0.004866
# 预训练Epoch [17300/20000] | 总损失: 94400.687500 | PDE损失: 0.770337 | IC/BC损失: 6.242022 | 拓扑约束损失: 0.004866
# 预训练Epoch [17400/20000] | 总损失: 493.411530 | PDE损失: 0.106309 | IC/BC损失: 0.025805 | 拓扑约束损失: 0.004863
# 预训练Epoch [17500/20000] | 总损失: 52892.726562 | PDE损失: 0.742563 | IC/BC损失: 3.476676 | 拓扑约束损失: 0.004863
# 预训练Epoch [17600/20000] | 总损失: 791470.562500 | PDE损失: 0.726311 | IC/BC损失: 52.716282 | 拓扑约束损失: 0.004862
# 预训练Epoch [17700/20000] | 总损失: 1143252.125000 | PDE损失: 0.231296 | IC/BC损失: 76.201393 | 拓扑约束损失: 0.004863
# 预训练Epoch [17800/20000] | 总损失: 23827.269531 | PDE损失: 0.121957 | IC/BC损失: 1.580353 | 拓扑约束损失: 0.004865
# 预训练Epoch [17900/20000] | 总损失: 171809.859375 | PDE损失: 0.282672 | IC/BC损失: 11.435143 | 拓扑约束损失: 0.004865
# 预训练Epoch [18000/20000] | 总损失: 644292.437500 | PDE损失: 0.354601 | IC/BC损失: 42.929188 | 拓扑约束损失: 0.004863
# 预训练Epoch [18100/20000] | 总损失: 258609.968750 | PDE损失: 0.768801 | IC/BC损失: 17.189409 | 拓扑约束损失: 0.004866
# 预训练Epoch [18200/20000] | 总损失: 42443.167969 | PDE损失: 0.138917 | IC/BC损失: 2.820282 | 拓扑约束损失: 0.004867
# 预训练Epoch [18300/20000] | 总损失: 11438.787109 | PDE损失: 0.086906 | IC/BC损失: 0.756790 | 拓扑约束损失: 0.004865
# 预训练Epoch [18400/20000] | 总损失: 97499.875000 | PDE损失: 0.438305 | IC/BC损失: 6.470770 | 拓扑约束损失: 0.004860
# 预训练Epoch [18500/20000] | 总损失: 457595.312500 | PDE损失: 1.366310 | IC/BC损失: 30.415264 | 拓扑约束损失: 0.004862
# 预训练Epoch [18600/20000] | 总损失: 38298.511719 | PDE损失: 0.336767 | IC/BC损失: 2.530782 | 拓扑约束损失: 0.004862
# 预训练Epoch [18700/20000] | 总损失: 53460.621094 | PDE损失: 1.429126 | IC/BC损失: 3.468765 | 拓扑约束损失: 0.004861
# 预训练Epoch [18800/20000] | 总损失: 546922.000000 | PDE损失: 16.879883 | IC/BC损失: 35.336143 | 拓扑约束损失: 0.004860
# 预训练Epoch [18900/20000] | 总损失: 936680.687500 | PDE损失: 8.736825 | IC/BC损失: 61.862926 | 拓扑约束损失: 0.004865
# 预训练Epoch [19000/20000] | 总损失: 118031.851562 | PDE损失: 2.321805 | IC/BC损失: 7.714002 | 拓扑约束损失: 0.004864
# 预训练Epoch [19100/20000] | 总损失: 134162.484375 | PDE损失: 0.906269 | IC/BC损失: 8.883746 | 拓扑约束损失: 0.004862
# 预训练Epoch [19200/20000] | 总损失: 154846.843750 | PDE损失: 1.872461 | IC/BC损失: 10.198290 | 拓扑约束损失: 0.004860
# 预训练Epoch [19300/20000] | 总损失: 78528.164062 | PDE损失: 0.532851 | IC/BC损失: 5.199686 | 拓扑约束损失: 0.004861
# 预训练Epoch [19400/20000] | 总损失: 85411.953125 | PDE损失: 0.248530 | IC/BC损失: 5.677560 | 拓扑约束损失: 0.004860
# 预训练Epoch [19500/20000] | 总损失: 449710.218750 | PDE损失: 0.296787 | IC/BC损失: 29.960894 | 拓扑约束损失: 0.004860
# 预训练Epoch [19600/20000] | 总损失: 14479037.000000 | PDE损失: 5.895150 | IC/BC损失: 964.876160 | 拓扑约束损失: 0.004860
# 预训练Epoch [19700/20000] | 总损失: 337195.093750 | PDE损失: 0.318681 | IC/BC损失: 22.458426 | 拓扑约束损失: 0.004860
# 预训练Epoch [19800/20000] | 总损失: 7194.538086 | PDE损失: 0.285992 | IC/BC损失: 0.460568 | 拓扑约束损失: 0.004860
# 预训练Epoch [19900/20000] | 总损失: 364107.906250 | PDE损失: 0.263947 | IC/BC损失: 24.256262 | 拓扑约束损失: 0.004860
# 预训练Epoch [20000/20000] | 总损失: 1473674.375000 | PDE损失: 0.291847 | IC/BC损失: 98.225502 | 拓扑约束损失: 0.004860
#
# ==================================================
# 开始精细优化（融合优化目标）
# ==================================================
# 精细优化Epoch [50/2000] | 总损失: 81618869843656704.000000 | PDE损失: 1557.474976 | 目标损失: 81618869843656704.000000 | 体积比: 0.000
# 精细优化Epoch [100/2000] | 总损失: 81661020652699648.000000 | PDE损失: 1557.474976 | 目标损失: 81661020652699648.000000 | 体积比: 0.000
# 精细优化Epoch [150/2000] | 总损失: 81654294733914112.000000 | PDE损失: 1557.474976 | 目标损失: 81654294733914112.000000 | 体积比: 0.000
